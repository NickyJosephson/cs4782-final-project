# %%
import sys, pathlib
sys.path.insert(0, str(pathlib.Path("../code").resolve()))
sys.path.insert(0, str(pathlib.Path("..").resolve()))

import torch
from data.datasets import get_loader

from model import build_unet
from degradation import Degradation
from evaluate import evaluate_model
from train import train

device= "cuda" if torch.cuda.is_available() else "cpu"

print("device: ", device)
# Out:
# /Users/krod/miniconda3/envs/summ25-env/lib/python3.10/site-packages/requests/__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# device:  cpu

# %%
#def train (dataset_name, num_steps= 100_000, lr= 2e-5, batch_size= 32, grad_accum_steps= 2, ema_decay= 0.995, ema_update_every= 10, log_every= 500, save_every= 5000, ckpt_dir= "../checkpoints", resume= False, device= None):
losses = train("celeba", 
      num_steps= 2, 
      lr= 2e-5, 
      batch_size= 32, 
      grad_accum_steps= 2, 
      ema_decay= 0.995, 
      ema_update_every= 10, 
      log_every= 500, 
      save_every= 5000, 
      ckpt_dir= "../checkpoints", 
      resume= False, 
      device= device)
# Out:
# [train] dataset= celeba device= cpu
# ---------------------------------------------------------------------------
# FileURLRetrievalError                     Traceback (most recent call last)
# File ~/miniconda3/envs/summ25-env/lib/python3.10/site-packages/gdown/download.py:301, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, resume, format, user_agent, log_messages, progress)
#     300 try:
# --> 301     url = get_url_from_gdrive_confirmation(res.text)
#     302 except FileURLRetrievalError as e:
#
# File ~/miniconda3/envs/summ25-env/lib/python3.10/site-packages/gdown/download.py:63, in get_url_from_gdrive_confirmation(contents)
#      62         error = m.groups()[0]
# ---> 63         raise FileURLRetrievalError(error)
#      64 if not url:
#
# FileURLRetrievalError: Too many users have viewed or downloaded this file recently. Please try accessing the file again later. If the file you are trying to access is particularly large or is shared with many people, it may take up to 24 hours to be able to view or download the file. If you still can't access a file after 24 hours, contact your domain administrator.
#
# During handling of the above exception, another exception occurred:
#
# FileURLRetrievalError                     Traceback (most recent call last)
# Cell In[2], line 2
#       1 #def train (dataset_name, num_steps= 100_000, lr= 2e-5, batch_size= 32, grad_accum_steps= 2, ema_decay= 0.995, ema_update_every= 10, log_every= 500, save_every= 5000, ckpt_dir= "../checkpoints", resume= False, device= None):
# ----> 2 losses = train("celeba",
#       3       num_steps= 2,
#       4       lr= 2e-5,
#       5       batch_size= 32,
#       6       grad_accum_steps= 2,
#       7       ema_decay= 0.995,
#       8       ema_update_every= 10,
#       9       log_every= 500,
#      10       save_every= 5000,
#      11       ckpt_dir= "../checkpoints",
#      12       resume= False,
#      13       device= device)
#
# File ~/Documents/finalproj/cs4782-final-project/code/train.py:23, in train(dataset_name, num_steps, lr, batch_size, grad_accum_steps, ema_decay, ema_update_every, log_every, save_every, ckpt_dir, resume, device)
#      20 print(f"[train] dataset= {dataset_name} device= {device}")
#      22 # data, model and degradation
# ---> 23 loader= get_loader(dataset_name, "train", batch_size=batch_size, num_workers= 2, shuffle= True)
#      24 deg_cfg= DEGRADATION_CONFIGS[dataset_name]
#      25 T = deg_cfg["num_timesteps"]
#
# File ~/Documents/finalproj/cs4782-final-project/data/datasets.py:141, in get_loader(name, split, batch_size, num_workers, augment, shuffle)
#     140 def get_loader(name: DatasetName, split: Split, batch_size: int, num_workers: int = 4, augment: bool = False, shuffle: Optional[bool] = None) -> DataLoader:
# --> 141     ds = get_dataset(name, split, augment=augment)
#     142     if shuffle is None:
#     143         shuffle = split == "train"
#
# File ~/Documents/finalproj/cs4782-final-project/data/datasets.py:128, in get_dataset(name, split, augment)
#     126     image_size = 64 if name == "celeba" else 128
#     127     tv_split = "valid" if split == "val" else split
# --> 128     return datasets.CelebA(str(root), split=tv_split, download=True, transform=_celeba_transform(image_size))
#     130 if name == "afhq":
#     131     subdir = "train" if split == "train" else "val"
#
# File ~/miniconda3/envs/summ25-env/lib/python3.10/site-packages/torchvision/datasets/celeba.py:85, in CelebA.__init__(self, root, split, target_type, transform, target_transform, download)
#      82     raise RuntimeError("target_transform is specified but target_type is empty")
#      84 if download:
# ---> 85     self.download()
#      87 if not self._check_integrity():
#      88     raise RuntimeError("Dataset not found or corrupted. You can use download=True to download it")
#
# File ~/miniconda3/envs/summ25-env/lib/python3.10/site-packages/torchvision/datasets/celeba.py:160, in CelebA.download(self)
#     157     return
#     159 for (file_id, md5, filename) in self.file_list:
# --> 160     download_file_from_google_drive(file_id, os.path.join(self.root, self.base_folder), filename, md5)
#     162 extract_archive(os.path.join(self.root, self.base_folder, "img_align_celeba.zip"))
#
# File ~/miniconda3/envs/summ25-env/lib/python3.10/site-packages/torchvision/datasets/utils.py:206, in download_file_from_google_drive(file_id, root, filename, md5)
#     203 if check_integrity(fpath, md5):
#     204     return
# --> 206 gdown.download(id=file_id, output=fpath, quiet=False, user_agent=USER_AGENT)
#     208 if not check_integrity(fpath, md5):
#     209     raise RuntimeError("File not found or corrupted.")
#
# File ~/miniconda3/envs/summ25-env/lib/python3.10/site-packages/gdown/download.py:312, in download(url, output, quiet, proxy, speed, use_cookies, verify, id, resume, format, user_agent, log_messages, progress)
#     302     except FileURLRetrievalError as e:
#     303         message = (
#     304             "Failed to retrieve file url:\n\n{}\n\n"
#     305             "You may still be able to access the file from the browser:"
#    (...)
#     310             url_origin,
#     311         )
# --> 312         raise FileURLRetrievalError(message)
#     314 filename_from_url = None
#     315 last_modified_time = None
#
# FileURLRetrievalError: Failed to retrieve file url:
#
# 	Too many users have viewed or downloaded this file recently. Please
# 	try accessing the file again later. If the file you are trying to
# 	access is particularly large or is shared with many people, it may
# 	take up to 24 hours to be able to view or download the file. If you
# 	still can't access a file after 24 hours, contact your domain
# 	administrator.
#
# You may still be able to access the file from the browser:
#
# 	https://drive.google.com/uc?id=0B7EVK8r0v71pZjFTYXZWM3FlRnM
#
# but Gdown can't. Please check connections and permissions.
