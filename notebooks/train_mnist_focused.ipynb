# %%
from google.colab import drive
import matplotlib.pyplot as plt
drive.mount("/content/drive")
repo = "/content/drive/MyDrive/cs4782-final-project"
# %cd {repo}
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/.shortcut-targets-by-id/1sEpnQZ0N_zNDz-lLP5-y8B9O1R28rUfJ/cs4782-final-project

# %%
# !pip install -q -r requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 3.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 19.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 68.3 MB/s eta 0:00:00

# %%
# Use this if ur getting errors with pillow version
# !pip uninstall -y pillow
# !pip install --no-cache-dir pillow==11.3.0

# %%
# import sys, pathlib
# sys.path.insert(0, str(pathlib.Path("../code").resolve()))
# sys.path.insert(0, str(pathlib.Path("..").resolve()))

import torch
from data.datasets import get_loader

from src.model import build_unet
from src.degradation import Degradation
from src.evaluate import evaluate_model
from src.train import train

device= "cuda" if torch.cuda.is_available() else "cpu"

print("device: ", device)
# Out:
# device:  cuda

# %%
#def train (dataset_name, num_steps= 100_000, lr= 2e-5, batch_size= 32, grad_accum_steps= 2, ema_decay= 0.995, ema_update_every= 10, log_every= 500, save_every= 5000, ckpt_dir= "../checkpoints", resume= False, device= None):
losses = train("mnist",
      num_steps= 100000,
      lr= 2e-5,
      batch_size= 32,
      grad_accum_steps= 2,
      ema_decay= 0.995,
      ema_update_every= 10,
      log_every= 500,
      save_every= 5000,
      ckpt_dir= "./checkpoints",
      degradation_type="gaussian_blur_focused",
      resume= False,
      device= device)
# Out:
# [train] dataset= mnist device= cuda
#  [train] step=     500 loss= 0.0416
#  [train] step=    1000 loss= 0.0185
#  [train] step=    1500 loss= 0.0154
#  [train] step=    2000 loss= 0.0139
#  [train] step=    2500 loss= 0.0129
#  [train] step=    3000 loss= 0.0123
#  [train] step=    3500 loss= 0.0117
#  [train] step=    4000 loss= 0.0113
#  [train] step=    4500 loss= 0.0110
#  [train] step=    5000 loss= 0.0106
# [train] saved ckpt at step 5000
#  [train] step=    5500 loss= 0.0104
#  [train] step=    6000 loss= 0.0101
#  [train] step=    6500 loss= 0.0099
#  [train] step=    7000 loss= 0.0096
#  [train] step=    7500 loss= 0.0095
#  [train] step=    8000 loss= 0.0093
#  [train] step=    8500 loss= 0.0090
#  [train] step=    9000 loss= 0.0089
#  [train] step=    9500 loss= 0.0086
#  [train] step=   10000 loss= 0.0086
# [train] saved ckpt at step 10000
#  [train] step=   10500 loss= 0.0084
#  [train] step=   11000 loss= 0.0084
#  [train] step=   11500 loss= 0.0081
#  [train] step=   12000 loss= 0.0080
#  [train] step=   12500 loss= 0.0080
#  [train] step=   13000 loss= 0.0078
#  [train] step=   13500 loss= 0.0076
#  [train] step=   14000 loss= 0.0075
#  [train] step=   14500 loss= 0.0074
#  [train] step=   15000 loss= 0.0074
# [train] saved ckpt at step 15000
#  [train] step=   15500 loss= 0.0073
#  [train] step=   16000 loss= 0.0071
#  [train] step=   16500 loss= 0.0070
#  [train] step=   17000 loss= 0.0069
#  [train] step=   17500 loss= 0.0069
#  [train] step=   18000 loss= 0.0069
#  [train] step=   18500 loss= 0.0067
#  [train] step=   19000 loss= 0.0067
#  [train] step=   19500 loss= 0.0067
#  [train] step=   20000 loss= 0.0065
# [train] saved ckpt at step 20000
#  [train] step=   20500 loss= 0.0064
#  [train] step=   21000 loss= 0.0065
#  [train] step=   21500 loss= 0.0064
#  [train] step=   22000 loss= 0.0063
#  [train] step=   22500 loss= 0.0062
#  [train] step=   23000 loss= 0.0063
#  [train] step=   23500 loss= 0.0061
#  [train] step=   63500 loss= 0.0040
#  [train] step=   64000 loss= 0.0040
#  [train] step=   64500 loss= 0.0041
#  [train] step=   65000 loss= 0.0039
# [train] saved ckpt at step 65000
#  [train] step=   65500 loss= 0.0041
#  [train] step=   66000 loss= 0.0039
#  [train] step=   66500 loss= 0.0040
#  [train] step=   67000 loss= 0.0039
#  [train] step=   67500 loss= 0.0039
#  [train] step=   68000 loss= 0.0039
#  [train] step=   68500 loss= 0.0039
#  [train] step=   69000 loss= 0.0038
#  [train] step=   69500 loss= 0.0038
#  [train] step=   70000 loss= 0.0038
# [train] saved ckpt at step 70000
#  [train] step=   70500 loss= 0.0038
#  [train] step=   71000 loss= 0.0039
#  [train] step=   71500 loss= 0.0038
#  [train] step=   72000 loss= 0.0038
#  [train] step=   72500 loss= 0.0037
#  [train] step=   73000 loss= 0.0038
#  [train] step=   73500 loss= 0.0037
#  [train] step=   74000 loss= 0.0037
#  [train] step=   74500 loss= 0.0038
#  [train] step=   75000 loss= 0.0036
# [train] saved ckpt at step 75000
#  [train] step=   75500 loss= 0.0037
#  [train] step=   76000 loss= 0.0036
#  [train] step=   76500 loss= 0.0037
#  [train] step=   77000 loss= 0.0037
#  [train] step=   77500 loss= 0.0036
#  [train] step=   78000 loss= 0.0037
#  [train] step=   78500 loss= 0.0036
#  [train] step=   79000 loss= 0.0036
#  [train] step=   79500 loss= 0.0036
#  [train] step=   80000 loss= 0.0036
# [train] saved ckpt at step 80000
#  [train] step=   80500 loss= 0.0035
#  [train] step=   81000 loss= 0.0035
#  [train] step=   81500 loss= 0.0036
#  [train] step=   82000 loss= 0.0036
#  [train] step=   82500 loss= 0.0036
#  [train] step=   83000 loss= 0.0035
#  [train] step=   83500 loss= 0.0035
#  [train] step=   84000 loss= 0.0035
#  [train] step=   84500 loss= 0.0035
#  [train] step=   85000 loss= 0.0035
# [train] saved ckpt at step 85000
#  [train] step=   85500 loss= 0.0035
#  [train] step=   86000 loss= 0.0035
#  [train] step=   86500 loss= 0.0036
#  [train] step=   87000 loss= 0.0035
#  [train] step=   87500 loss= 0.0034
#  [train] step=   88000 loss= 0.0034
#  [train] step=   88500 loss= 0.0035
#  [train] step=   89000 loss= 0.0034
#  [train] step=   89500 loss= 0.0033
#  [train] step=   90000 loss= 0.0035
# [train] saved ckpt at step 90000
#  [train] step=   90500 loss= 0.0034
#  [train] step=   91000 loss= 0.0034
#  [train] step=   91500 loss= 0.0033
#  [train] step=   92000 loss= 0.0034
#  [train] step=   92500 loss= 0.0033
#  [train] step=   93000 loss= 0.0033
#  [train] step=   93500 loss= 0.0034
#  [train] step=   94000 loss= 0.0033
#  [train] step=   94500 loss= 0.0033
#  [train] step=   95000 loss= 0.0033
# [train] saved ckpt at step 95000
#  [train] step=   95500 loss= 0.0033
#  [train] step=   96000 loss= 0.0033
#  [train] step=   96500 loss= 0.0032
#  [train] step=   97000 loss= 0.0033
#  [train] step=   97500 loss= 0.0033
#  [train] step=   98000 loss= 0.0033
#  [train] step=   98500 loss= 0.0032
#  [train] step=   99000 loss= 0.0032
#  [train] step=   99500 loss= 0.0033
#  [train] step=  100000 loss= 0.0032
# [train] saved ckpt at step 100000
# [train] done.

# %%
for step, loss in losses:
    print(f"Step: {step}, Loss: {loss:.4f}")

plt.plot([step for step, loss in losses], [loss for step, loss in losses])
