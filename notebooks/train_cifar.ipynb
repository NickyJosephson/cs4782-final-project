# %%
from google.colab import drive
import matplotlib.pyplot as plt
drive.mount("/content/drive")
repo = "/content/drive/MyDrive/cs4782-final-project"
# %cd {repo}
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/cs4782-final-project

# %%
# !pip install -q -r requirements.txt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 5.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 71.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 93.3 MB/s eta 0:00:00

# %%
# Use this if ur getting errors with pillow version
# !pip uninstall -y pillow
# !pip install --no-cache-dir pillow==11.3.0
# Out:
# Found existing installation: pillow 11.3.0
# Uninstalling pillow-11.3.0:
#   Successfully uninstalled pillow-11.3.0
# Collecting pillow==11.3.0
#   Downloading pillow-11.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.0 kB)
# Downloading pillow-11.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 260.2 MB/s eta 0:00:00
# Installing collected packages: pillow
# Successfully installed pillow-11.3.0

# %%
# import sys, pathlib
# sys.path.insert(0, str(pathlib.Path("../code").resolve()))
# sys.path.insert(0, str(pathlib.Path("..").resolve()))

import torch
from data.datasets import get_loader

from src.model import build_unet
from src.degradation import Degradation
from src.evaluate import evaluate_model
from src.train import train

device= "cuda" if torch.cuda.is_available() else "cpu"

print("device: ", device)
# Out:
# device:  cuda

# %%
#def train (dataset_name, num_steps= 100_000, lr= 2e-5, batch_size= 32, grad_accum_steps= 2, ema_decay= 0.995, ema_update_every= 10, log_every= 500, save_every= 5000, ckpt_dir= "../checkpoints", resume= False, device= None):
losses = train("cifar10",
      num_steps= 100000,
      lr= 2e-5,
      batch_size= 128,
      grad_accum_steps= 2,
      ema_decay= 0.995,
      ema_update_every= 10,
      log_every= 500,
      save_every= 5000,
      ckpt_dir= "./checkpoints",
      resume= True,
      device= device)
# Out:
# [train] dataset= cifar10 device= cuda
# [train] resumed from step 90000
#  [train] step=   90500 loss= 0.0104
#  [train] step=   91000 loss= 0.0103
#  [train] step=   91500 loss= 0.0103
#  [train] step=   92000 loss= 0.0103
#  [train] step=   92500 loss= 0.0103
#  [train] step=   93000 loss= 0.0102
#  [train] step=   93500 loss= 0.0102
#  [train] step=   94000 loss= 0.0102
#  [train] step=   94500 loss= 0.0102
#  [train] step=   95000 loss= 0.0102
# [train] saved ckpt at step 95000
#  [train] step=   95500 loss= 0.0101
#  [train] step=   96000 loss= 0.0101
#  [train] step=   96500 loss= 0.0101
#  [train] step=   97000 loss= 0.0101
#  [train] step=   97500 loss= 0.0101
#  [train] step=   98000 loss= 0.0100
#  [train] step=   98500 loss= 0.0100
#  [train] step=   99000 loss= 0.0100
#  [train] step=   99500 loss= 0.0100
#  [train] step=  100000 loss= 0.0100
# [train] saved ckpt at step 100000
# [train] done.
